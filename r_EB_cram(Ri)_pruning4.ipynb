# %% [markdown]
# <a href="https://colab.research.google.com/github/Lokuhu/112-2_2LNN/blob/main/r_EB_cram(Ri)_pruning4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %%
# 試算表>檔案>共用>發布到網路 即可於colab中讀取
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vQhbAejyGUXlZltX2nsbC4sTw890L6081piAP8ZDJVbufqZ9xm-S5P7gIrXnpgszm-U9SmEkBxJc5uF/pub?gid=1265524659&single=true&output=csv'
seed = pd.read_csv(url)

# %%
seed['Type'] = seed['Type'].replace(1, 0.0)
seed['Type'] = seed['Type'].replace(2, 1.0)
seed['Type'] = seed['Type'].replace(3, 2.0)
seed
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0    15.26      14.84       0.8710          5.763         3.312
# 1    14.88      14.57       0.8811          5.554         3.333
# 2    14.29      14.09       0.9050          5.291         3.337
# 3    13.84      13.94       0.8955          5.324         3.379
# 4    16.14      14.99       0.9034          5.658         3.562
# ..     ...        ...          ...            ...           ...
# 205  12.19      13.20       0.8783          5.137         2.981
# 206  11.23      12.88       0.8511          5.140         2.795
# 207  13.20      13.66       0.8883          5.236         3.232
# 208  11.84      13.21       0.8521          5.175         2.836
# 209  12.30      13.34       0.8684          5.243         2.974
#
#      Asymmetry.Coeff  Kernel.Groove  Type
# 0              2.221          5.220     0
# 1              1.018          4.956     0
# 2              2.699          4.825     0
# 3              2.259          4.805     0
# 4              1.355          5.175     0
# ..               ...            ...   ...
# 205            3.631          4.870     2
# 206            4.325          5.003     2
# 207            8.315          5.056     2
# 208            3.598          5.044     2
# 209            5.637          5.063     2
#
# [210 rows x 8 columns]

# %%
# Split data
X = seed.drop('Type',axis=1)
y = seed['Type']

# Covert these to numpy arr
X = X.values
y = y.values

# 20%test, 80%training
X_train, X_test, y_train, y_test=train_test_split (X, y ,test_size = 0.2, random_state = 30)

# Covert X and y to float tensors
X_train = torch.FloatTensor(X_train)
X_test = torch.FloatTensor(X_test)
y_train = torch.LongTensor(y_train)
y_test = torch.LongTensor(y_test)

# %%
class Model5(nn.Module):
    def __init__(self, in_features=7, h1=11, out_features=3):
        super().__init__()
        self.fc1 = nn.Linear(in_features, h1)
        self.dropout = nn.Dropout(p=0.5)  # 添加 Dropout
        self.out = nn.Linear(h1, out_features)

    def forward(self, x):

        x=F.relu(self.fc1(x))
        x = self.dropout(x)  # 在激活函數之後和輸出層之前添加 Dropout
        x=F.relu(self.out(x))

        #x = torch.tanh(self.fc1(x))
        #x = self.dropout(x)  # 在激活函數之後和輸出層之前添加 Dropout
        #x = torch.tanh(self.out(x))
        return x

# %%
def prune_hidden_node_based_on_weight(model, X_train, y_train, criterion, prune_threshold=0.01):
    # 找到output layer權重絕對值最小的隱藏節點
    h1 = model.fc1.weight.size(0)
    # 印一下修剪前的隱藏節點數
    print(f"Number of hidden nodes before pruning: {h1}")

    out_weights_abs = model.out.weight.abs().sum(dim=0)
    k = torch.argmin(out_weights_abs).item()

    if h1 <= 1:
        return model  # 保證至少有一個隱藏節點

    new_h1 = h1 - 1
    new_model = Model5(in_features=7, h1=new_h1, out_features=3)

    with torch.no_grad():
        new_model.fc1.weight = nn.Parameter(torch.cat((model.fc1.weight[:k], model.fc1.weight[k+1:])))
        new_model.fc1.bias = nn.Parameter(torch.cat((model.fc1.bias[:k], model.fc1.bias[k+1:])))
        new_model.out.weight = nn.Parameter(torch.cat((model.out.weight[:, :k], model.out.weight[:, k+1:]), dim=1))
        new_model.out.bias = model.out.bias

    # 計算新損失
    y_pred = new_model(X_train)
    new_loss = criterion(y_pred, y_train)

    # 如果新的損失在可接受範圍內，則保留修剪後的模型
    if new_loss.item() < prune_threshold:
        #print(f"Number of hidden nodes after pruning: {new_h1}")
        return new_model

    # 印一下修剪後的隱藏節點數
    print(f"Number of hidden nodes after pruning: {h1} (no pruning done)")
    return model


# Cramming module: 加上新的hidden nodes，調整權重
def cramming(model, X_train, y_train, epoch):
    criterion = nn.CrossEntropyLoss() #定義loss function
    model.eval()
    with torch.no_grad():
        y_pred = model(X_train)
        if epoch % 10 == 0:
            print(f"Epoch {epoch}: Cramming phase loss: {criterion(y_pred, y_train).item()}")

    # 找出所有分類錯誤的樣本的index
    incorrect_indices = (y_pred.argmax(dim=1) != y_train).nonzero(as_tuple=True)[0]
    #print("Incorrect indices:", incorrect_indices)

    if len(incorrect_indices) == 0:
        return model

    for i in incorrect_indices:
        new_h1 = model.fc1.weight.size(0) + 3
        new_model = Model5(in_features=7, h1=new_h1, out_features=3)

        with torch.no_grad():
            new_model.fc1.weight[:-3] = model.fc1.weight
            new_model.fc1.bias[:-3] = model.fc1.bias

            new_model.fc1.weight[-3] = X_train[i]
            new_model.fc1.weight[-2] = X_train[i] * 0.5  # Example transformation
            new_model.fc1.weight[-1] = X_train[i] * -0.5

            new_model.fc1.bias[-3] = 1 - X_train[i].sum()
            new_model.fc1.bias[-2] = 1 - (X_train[i] * 0.5).sum()
            new_model.fc1.bias[-1] = 1 - (X_train[i] * -0.5).sum()

            print(f"對 misclassified index {i} 加入三個隱藏節點")

            new_model.out.weight[:, :-3] = model.out.weight
            new_model.out.weight[:, -3:] = 0.0
            new_model.out.bias = model.out.bias

        model = new_model
    return model

# %%
def train_model(model, X_train, y_train, epochs, lr, prune_threshold=0.01):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=0.9)
    losses = []

    for epoch in range(epochs):
        model.train()
        optimizer.zero_grad()
        y_pred = model(X_train)
        loss = criterion(y_pred, y_train)
        losses.append(loss.item())

        if epoch % 10 == 0:
            print(f'Epoch: {epoch} Total Loss: {loss.item()}')

        loss.backward()
        optimizer.step()

        # 每個EB後逐步修剪不相關的隱藏節點
        model = prune_hidden_node_based_on_weight(model, X_train, y_train, criterion, prune_threshold=0.01)
        # 如果有錯誤預測，進行cramming
        model = cramming(model, X_train, y_train, epoch)
    print(f"{losses}")
    return model, losses

# %%
# 訓練並評估模型
torch.manual_seed(41)
model5 = Model5()
model5, losses = train_model(model5, X_train, y_train, epochs=100, lr=0.01)
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# 對 misclassified index 134 加入三個隱藏節點
# 對 misclassified index 137 加入三個隱藏節點
# 對 misclassified index 139 加入三個隱藏節點
# 對 misclassified index 143 加入三個隱藏節點
# 對 misclassified index 144 加入三個隱藏節點
# 對 misclassified index 145 加入三個隱藏節點
# 對 misclassified index 146 加入三個隱藏節點
# 對 misclassified index 147 加入三個隱藏節點
# 對 misclassified index 149 加入三個隱藏節點
# 對 misclassified index 150 加入三個隱藏節點
# 對 misclassified index 151 加入三個隱藏節點
# 對 misclassified index 152 加入三個隱藏節點
# 對 misclassified index 154 加入三個隱藏節點
# 對 misclassified index 156 加入三個隱藏節點
# 對 misclassified index 157 加入三個隱藏節點
# 對 misclassified index 158 加入三個隱藏節點
# 對 misclassified index 159 加入三個隱藏節點
# 對 misclassified index 161 加入三個隱藏節點
# 對 misclassified index 162 加入三個隱藏節點
# 對 misclassified index 163 加入三個隱藏節點
# 對 misclassified index 165 加入三個隱藏節點
# 對 misclassified index 166 加入三個隱藏節點
# Number of hidden nodes after pruning: 18659 (no pruning done)
# 對 misclassified index 1 加入三個隱藏節點
# 對 misclassified index 2 加入三個隱藏節點
# 對 misclassified index 3 加入三個隱藏節點
# 對 misclassified index 5 加入三個隱藏節點
# 對 misclassified index 7 加入三個隱藏節點
# 對 misclassified index 8 加入三個隱藏節點
# 對 misclassified index 12 加入三個隱藏節點
# 對 misclassified index 14 加入三個隱藏節點
# 對 misclassified index 16 加入三個隱藏節點
# 對 misclassified index 18 加入三個隱藏節點
# 對 misclassified index 19 加入三個隱藏節點
# 對 misclassified index 20 加入三個隱藏節點
# 對 misclassified index 21 加入三個隱藏節點
# 對 misclassified index 23 加入三個隱藏節點
# 對 misclassified index 25 加入三個隱藏節點
# 對 misclassified index 26 加入三個隱藏節點
# 對 misclassified index 27 加入三個隱藏節點
# 對 misclassified index 28 加入三個隱藏節點
# 對 misclassified index 29 加入三個隱藏節點
# 對 misclassified index 31 加入三個隱藏節點
# 對 misclassified index 33 加入三個隱藏節點
# 對 misclassified index 34 加入三個隱藏節點
# 對 misclassified index 35 加入三個隱藏節點
# 對 misclassified index 39 加入三個隱藏節點
# 對 misclassified index 40 加入三個隱藏節點
# 對 misclassified index 43 加入三個隱藏節點
# 對 misclassified index 44 加入三個隱藏節點
# 對 misclassified index 45 加入三個隱藏節點
# 對 misclassified index 46 加入三個隱藏節點
# 對 misclassified index 47 加入三個隱藏節點
# 對 misclassified index 49 加入三個隱藏節點
# 對 misclassified index 50 加入三個隱藏節點
# 對 misclassified index 51 加入三個隱藏節點
# 對 misclassified index 52 加入三個隱藏節點
# 對 misclassified index 53 加入三個隱藏節點
# 對 misclassified index 54 加入三個隱藏節點
# 對 misclassified index 55 加入三個隱藏節點
# 對 misclassified index 56 加入三個隱藏節點
# 對 misclassified index 57 加入三個隱藏節點
# 對 misclassified index 59 加入三個隱藏節點
# 對 misclassified index 60 加入三個隱藏節點
# 對 misclassified index 61 加入三個隱藏節點
# 對 misclassified index 63 加入三個隱藏節點
# 對 misclassified index 64 加入三個隱藏節點
# 對 misclassified index 65 加入三個隱藏節點
# 對 misclassified index 68 加入三個隱藏節點
# 對 misclassified index 69 加入三個隱藏節點
# 對 misclassified index 70 加入三個隱藏節點
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# 對 misclassified index 134 加入三個隱藏節點
# 對 misclassified index 137 加入三個隱藏節點
# 對 misclassified index 139 加入三個隱藏節點
# 對 misclassified index 143 加入三個隱藏節點
# 對 misclassified index 144 加入三個隱藏節點
# 對 misclassified index 145 加入三個隱藏節點
# 對 misclassified index 146 加入三個隱藏節點
# 對 misclassified index 147 加入三個隱藏節點
# 對 misclassified index 149 加入三個隱藏節點
# 對 misclassified index 150 加入三個隱藏節點
# 對 misclassified index 151 加入三個隱藏節點
# 對 misclassified index 152 加入三個隱藏節點
# 對 misclassified index 154 加入三個隱藏節點
# 對 misclassified index 156 加入三個隱藏節點
# 對 misclassified index 157 加入三個隱藏節點
# 對 misclassified index 158 加入三個隱藏節點
# 對 misclassified index 159 加入三個隱藏節點
# 對 misclassified index 161 加入三個隱藏節點
# 對 misclassified index 162 加入三個隱藏節點
# 對 misclassified index 163 加入三個隱藏節點
# 對 misclassified index 165 加入三個隱藏節點
# 對 misclassified index 166 加入三個隱藏節點
# Number of hidden nodes after pruning: 18992 (no pruning done)
# 對 misclassified index 1 加入三個隱藏節點
# 對 misclassified index 2 加入三個隱藏節點
# 對 misclassified index 3 加入三個隱藏節點
# 對 misclassified index 5 加入三個隱藏節點
# 對 misclassified index 7 加入三個隱藏節點
# 對 misclassified index 8 加入三個隱藏節點
# 對 misclassified index 12 加入三個隱藏節點
# 對 misclassified index 14 加入三個隱藏節點
# 對 misclassified index 16 加入三個隱藏節點
# 對 misclassified index 18 加入三個隱藏節點
# 對 misclassified index 19 加入三個隱藏節點
# 對 misclassified index 20 加入三個隱藏節點
# 對 misclassified index 21 加入三個隱藏節點
# 對 misclassified index 23 加入三個隱藏節點
# 對 misclassified index 25 加入三個隱藏節點
# 對 misclassified index 26 加入三個隱藏節點
# 對 misclassified index 27 加入三個隱藏節點
# 對 misclassified index 28 加入三個隱藏節點
# 對 misclassified index 29 加入三個隱藏節點
# 對 misclassified index 31 加入三個隱藏節點
# 對 misclassified index 33 加入三個隱藏節點
# 對 misclassified index 34 加入三個隱藏節點
# 對 misclassified index 35 加入三個隱藏節點
# 對 misclassified index 39 加入三個隱藏節點
# 對 misclassified index 40 加入三個隱藏節點
# 對 misclassified index 43 加入三個隱藏節點
# 對 misclassified index 44 加入三個隱藏節點
# 對 misclassified index 45 加入三個隱藏節點
# 對 misclassified index 46 加入三個隱藏節點
# 對 misclassified index 47 加入三個隱藏節點
# 對 misclassified index 49 加入三個隱藏節點
# 對 misclassified index 50 加入三個隱藏節點
# 對 misclassified index 51 加入三個隱藏節點
# 對 misclassified index 52 加入三個隱藏節點
# 對 misclassified index 53 加入三個隱藏節點
# 對 misclassified index 54 加入三個隱藏節點
# 對 misclassified index 55 加入三個隱藏節點
# 對 misclassified index 56 加入三個隱藏節點
# 對 misclassified index 57 加入三個隱藏節點
# 對 misclassified index 59 加入三個隱藏節點
# 對 misclassified index 60 加入三個隱藏節點
# 對 misclassified index 61 加入三個隱藏節點
# 對 misclassified index 63 加入三個隱藏節點
# 對 misclassified index 64 加入三個隱藏節點
# 對 misclassified index 65 加入三個隱藏節點
# 對 misclassified index 68 加入三個隱藏節點
# 對 misclassified index 69 加入三個隱藏節點
# 對 misclassified index 70 加入三個隱藏節點
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# 對 misclassified index 134 加入三個隱藏節點
# 對 misclassified index 137 加入三個隱藏節點
# 對 misclassified index 139 加入三個隱藏節點
# 對 misclassified index 143 加入三個隱藏節點
# 對 misclassified index 144 加入三個隱藏節點
# 對 misclassified index 145 加入三個隱藏節點
# 對 misclassified index 146 加入三個隱藏節點
# 對 misclassified index 147 加入三個隱藏節點
# 對 misclassified index 149 加入三個隱藏節點
# 對 misclassified index 150 加入三個隱藏節點
# 對 misclassified index 151 加入三個隱藏節點
# 對 misclassified index 152 加入三個隱藏節點
# 對 misclassified index 154 加入三個隱藏節點
# 對 misclassified index 156 加入三個隱藏節點
# 對 misclassified index 157 加入三個隱藏節點
# 對 misclassified index 158 加入三個隱藏節點
# 對 misclassified index 159 加入三個隱藏節點
# 對 misclassified index 161 加入三個隱藏節點
# 對 misclassified index 162 加入三個隱藏節點
# 對 misclassified index 163 加入三個隱藏節點
# 對 misclassified index 165 加入三個隱藏節點
# 對 misclassified index 166 加入三個隱藏節點
# Number of hidden nodes after pruning: 19325 (no pruning done)
# 對 misclassified index 1 加入三個隱藏節點
# 對 misclassified index 2 加入三個隱藏節點
# 對 misclassified index 3 加入三個隱藏節點
# 對 misclassified index 5 加入三個隱藏節點
# 對 misclassified index 7 加入三個隱藏節點
# 對 misclassified index 8 加入三個隱藏節點
# 對 misclassified index 12 加入三個隱藏節點
# 對 misclassified index 14 加入三個隱藏節點
# 對 misclassified index 16 加入三個隱藏節點
# 對 misclassified index 18 加入三個隱藏節點
# 對 misclassified index 19 加入三個隱藏節點
# 對 misclassified index 20 加入三個隱藏節點
# 對 misclassified index 21 加入三個隱藏節點
# 對 misclassified index 23 加入三個隱藏節點
# 對 misclassified index 25 加入三個隱藏節點
# 對 misclassified index 26 加入三個隱藏節點
# 對 misclassified index 27 加入三個隱藏節點
# 對 misclassified index 28 加入三個隱藏節點
# 對 misclassified index 29 加入三個隱藏節點
# 對 misclassified index 31 加入三個隱藏節點
# 對 misclassified index 33 加入三個隱藏節點
# 對 misclassified index 34 加入三個隱藏節點
# 對 misclassified index 35 加入三個隱藏節點
# 對 misclassified index 39 加入三個隱藏節點
# 對 misclassified index 40 加入三個隱藏節點
# 對 misclassified index 43 加入三個隱藏節點
# 對 misclassified index 44 加入三個隱藏節點
# 對 misclassified index 45 加入三個隱藏節點
# 對 misclassified index 46 加入三個隱藏節點
# 對 misclassified index 47 加入三個隱藏節點
# 對 misclassified index 49 加入三個隱藏節點
# 對 misclassified index 50 加入三個隱藏節點
# 對 misclassified index 51 加入三個隱藏節點
# 對 misclassified index 52 加入三個隱藏節點
# 對 misclassified index 53 加入三個隱藏節點
# 對 misclassified index 54 加入三個隱藏節點
# 對 misclassified index 55 加入三個隱藏節點
# 對 misclassified index 56 加入三個隱藏節點
# 對 misclassified index 57 加入三個隱藏節點
# 對 misclassified index 59 加入三個隱藏節點
# 對 misclassified index 60 加入三個隱藏節點
# 對 misclassified index 61 加入三個隱藏節點
# 對 misclassified index 63 加入三個隱藏節點
# 對 misclassified index 64 加入三個隱藏節點
# 對 misclassified index 65 加入三個隱藏節點
# 對 misclassified index 68 加入三個隱藏節點
# 對 misclassified index 69 加入三個隱藏節點
# 對 misclassified index 70 加入三個隱藏節點
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# 對 misclassified index 134 加入三個隱藏節點
# 對 misclassified index 137 加入三個隱藏節點
# 對 misclassified index 139 加入三個隱藏節點
# 對 misclassified index 143 加入三個隱藏節點
# 對 misclassified index 144 加入三個隱藏節點
# 對 misclassified index 145 加入三個隱藏節點
# 對 misclassified index 146 加入三個隱藏節點
# 對 misclassified index 147 加入三個隱藏節點
# 對 misclassified index 149 加入三個隱藏節點
# 對 misclassified index 150 加入三個隱藏節點
# 對 misclassified index 151 加入三個隱藏節點
# 對 misclassified index 152 加入三個隱藏節點
# 對 misclassified index 154 加入三個隱藏節點
# 對 misclassified index 156 加入三個隱藏節點
# 對 misclassified index 157 加入三個隱藏節點
# 對 misclassified index 158 加入三個隱藏節點
# 對 misclassified index 159 加入三個隱藏節點
# 對 misclassified index 161 加入三個隱藏節點
# 對 misclassified index 162 加入三個隱藏節點
# 對 misclassified index 163 加入三個隱藏節點
# 對 misclassified index 165 加入三個隱藏節點
# 對 misclassified index 166 加入三個隱藏節點
# Number of hidden nodes after pruning: 19658 (no pruning done)
# 對 misclassified index 1 加入三個隱藏節點
# 對 misclassified index 2 加入三個隱藏節點
# 對 misclassified index 3 加入三個隱藏節點
# 對 misclassified index 5 加入三個隱藏節點
# 對 misclassified index 7 加入三個隱藏節點
# 對 misclassified index 8 加入三個隱藏節點
# 對 misclassified index 12 加入三個隱藏節點
# 對 misclassified index 14 加入三個隱藏節點
# 對 misclassified index 16 加入三個隱藏節點
# 對 misclassified index 18 加入三個隱藏節點
# 對 misclassified index 19 加入三個隱藏節點
# 對 misclassified index 20 加入三個隱藏節點
# 對 misclassified index 21 加入三個隱藏節點
# 對 misclassified index 23 加入三個隱藏節點
# 對 misclassified index 25 加入三個隱藏節點
# 對 misclassified index 26 加入三個隱藏節點
# 對 misclassified index 27 加入三個隱藏節點
# 對 misclassified index 28 加入三個隱藏節點
# 對 misclassified index 29 加入三個隱藏節點
# 對 misclassified index 31 加入三個隱藏節點
# 對 misclassified index 33 加入三個隱藏節點
# 對 misclassified index 34 加入三個隱藏節點
# 對 misclassified index 35 加入三個隱藏節點
# 對 misclassified index 39 加入三個隱藏節點
# 對 misclassified index 40 加入三個隱藏節點
# 對 misclassified index 43 加入三個隱藏節點
# 對 misclassified index 44 加入三個隱藏節點
# 對 misclassified index 45 加入三個隱藏節點
# 對 misclassified index 46 加入三個隱藏節點
# 對 misclassified index 47 加入三個隱藏節點
# 對 misclassified index 49 加入三個隱藏節點
# 對 misclassified index 50 加入三個隱藏節點
# 對 misclassified index 51 加入三個隱藏節點
# 對 misclassified index 52 加入三個隱藏節點
# 對 misclassified index 53 加入三個隱藏節點
# 對 misclassified index 54 加入三個隱藏節點
# 對 misclassified index 55 加入三個隱藏節點
# 對 misclassified index 56 加入三個隱藏節點
# 對 misclassified index 57 加入三個隱藏節點
# 對 misclassified index 59 加入三個隱藏節點
# 對 misclassified index 60 加入三個隱藏節點
# 對 misclassified index 61 加入三個隱藏節點
# 對 misclassified index 63 加入三個隱藏節點
# 對 misclassified index 64 加入三個隱藏節點
# 對 misclassified index 65 加入三個隱藏節點
# 對 misclassified index 68 加入三個隱藏節點
# 對 misclassified index 69 加入三個隱藏節點
# 對 misclassified index 70 加入三個隱藏節點
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# 對 misclassified index 134 加入三個隱藏節點
# 對 misclassified index 137 加入三個隱藏節點
# 對 misclassified index 139 加入三個隱藏節點
# 對 misclassified index 143 加入三個隱藏節點
# 對 misclassified index 144 加入三個隱藏節點
# 對 misclassified index 145 加入三個隱藏節點
# 對 misclassified index 146 加入三個隱藏節點
# 對 misclassified index 147 加入三個隱藏節點
# 對 misclassified index 149 加入三個隱藏節點
# 對 misclassified index 150 加入三個隱藏節點
# 對 misclassified index 151 加入三個隱藏節點
# 對 misclassified index 152 加入三個隱藏節點
# 對 misclassified index 154 加入三個隱藏節點
# 對 misclassified index 156 加入三個隱藏節點
# 對 misclassified index 157 加入三個隱藏節點
# 對 misclassified index 158 加入三個隱藏節點
# 對 misclassified index 159 加入三個隱藏節點
# 對 misclassified index 161 加入三個隱藏節點
# 對 misclassified index 162 加入三個隱藏節點
# 對 misclassified index 163 加入三個隱藏節點
# 對 misclassified index 165 加入三個隱藏節點
# 對 misclassified index 166 加入三個隱藏節點
# Epoch: 60 Total Loss: 1.3330484628677368
# Number of hidden nodes after pruning: 19991 (no pruning done)
# Epoch 60: Cramming phase loss: 1.0986120700836182
# 對 misclassified index 1 加入三個隱藏節點
# 對 misclassified index 2 加入三個隱藏節點
# 對 misclassified index 3 加入三個隱藏節點
# 對 misclassified index 5 加入三個隱藏節點
# 對 misclassified index 7 加入三個隱藏節點
# 對 misclassified index 8 加入三個隱藏節點
# 對 misclassified index 12 加入三個隱藏節點
# 對 misclassified index 14 加入三個隱藏節點
# 對 misclassified index 16 加入三個隱藏節點
# 對 misclassified index 18 加入三個隱藏節點
# 對 misclassified index 19 加入三個隱藏節點
# 對 misclassified index 20 加入三個隱藏節點
# 對 misclassified index 21 加入三個隱藏節點
# 對 misclassified index 23 加入三個隱藏節點
# 對 misclassified index 25 加入三個隱藏節點
# 對 misclassified index 26 加入三個隱藏節點
# 對 misclassified index 27 加入三個隱藏節點
# 對 misclassified index 28 加入三個隱藏節點
# 對 misclassified index 29 加入三個隱藏節點
# 對 misclassified index 31 加入三個隱藏節點
# 對 misclassified index 33 加入三個隱藏節點
# 對 misclassified index 34 加入三個隱藏節點
# 對 misclassified index 35 加入三個隱藏節點
# 對 misclassified index 39 加入三個隱藏節點
# 對 misclassified index 40 加入三個隱藏節點
# 對 misclassified index 43 加入三個隱藏節點
# 對 misclassified index 44 加入三個隱藏節點
# 對 misclassified index 45 加入三個隱藏節點
# 對 misclassified index 46 加入三個隱藏節點
# 對 misclassified index 47 加入三個隱藏節點
# 對 misclassified index 49 加入三個隱藏節點
# 對 misclassified index 50 加入三個隱藏節點
# 對 misclassified index 51 加入三個隱藏節點
# 對 misclassified index 52 加入三個隱藏節點
# 對 misclassified index 53 加入三個隱藏節點
# 對 misclassified index 54 加入三個隱藏節點
# 對 misclassified index 55 加入三個隱藏節點
# 對 misclassified index 56 加入三個隱藏節點
# 對 misclassified index 57 加入三個隱藏節點
# 對 misclassified index 59 加入三個隱藏節點
# 對 misclassified index 60 加入三個隱藏節點
# 對 misclassified index 61 加入三個隱藏節點
# 對 misclassified index 63 加入三個隱藏節點
# 對 misclassified index 64 加入三個隱藏節點
# 對 misclassified index 65 加入三個隱藏節點
# 對 misclassified index 68 加入三個隱藏節點
# 對 misclassified index 69 加入三個隱藏節點
# 對 misclassified index 70 加入三個隱藏節點
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# 對 misclassified index 134 加入三個隱藏節點
# 對 misclassified index 137 加入三個隱藏節點
# 對 misclassified index 139 加入三個隱藏節點
# 對 misclassified index 143 加入三個隱藏節點
# 對 misclassified index 144 加入三個隱藏節點
# 對 misclassified index 145 加入三個隱藏節點
# 對 misclassified index 146 加入三個隱藏節點
# 對 misclassified index 147 加入三個隱藏節點
# 對 misclassified index 149 加入三個隱藏節點
# 對 misclassified index 150 加入三個隱藏節點
# 對 misclassified index 151 加入三個隱藏節點
# 對 misclassified index 152 加入三個隱藏節點
# 對 misclassified index 154 加入三個隱藏節點
# 對 misclassified index 156 加入三個隱藏節點
# 對 misclassified index 157 加入三個隱藏節點
# 對 misclassified index 158 加入三個隱藏節點
# 對 misclassified index 159 加入三個隱藏節點
# 對 misclassified index 161 加入三個隱藏節點
# 對 misclassified index 162 加入三個隱藏節點
# 對 misclassified index 163 加入三個隱藏節點
# 對 misclassified index 165 加入三個隱藏節點
# 對 misclassified index 166 加入三個隱藏節點
# Number of hidden nodes after pruning: 20324 (no pruning done)
# 對 misclassified index 1 加入三個隱藏節點
# 對 misclassified index 2 加入三個隱藏節點
# 對 misclassified index 3 加入三個隱藏節點
# 對 misclassified index 5 加入三個隱藏節點
# 對 misclassified index 7 加入三個隱藏節點
# 對 misclassified index 8 加入三個隱藏節點
# 對 misclassified index 12 加入三個隱藏節點
# 對 misclassified index 14 加入三個隱藏節點
# 對 misclassified index 16 加入三個隱藏節點
# 對 misclassified index 18 加入三個隱藏節點
# 對 misclassified index 19 加入三個隱藏節點
# 對 misclassified index 20 加入三個隱藏節點
# 對 misclassified index 21 加入三個隱藏節點
# 對 misclassified index 23 加入三個隱藏節點
# 對 misclassified index 25 加入三個隱藏節點
# 對 misclassified index 26 加入三個隱藏節點
# 對 misclassified index 27 加入三個隱藏節點
# 對 misclassified index 28 加入三個隱藏節點
# 對 misclassified index 29 加入三個隱藏節點
# 對 misclassified index 31 加入三個隱藏節點
# 對 misclassified index 33 加入三個隱藏節點
# 對 misclassified index 34 加入三個隱藏節點
# 對 misclassified index 35 加入三個隱藏節點
# 對 misclassified index 39 加入三個隱藏節點
# 對 misclassified index 40 加入三個隱藏節點
# 對 misclassified index 43 加入三個隱藏節點
# 對 misclassified index 44 加入三個隱藏節點
# 對 misclassified index 45 加入三個隱藏節點
# 對 misclassified index 46 加入三個隱藏節點
# 對 misclassified index 47 加入三個隱藏節點
# 對 misclassified index 49 加入三個隱藏節點
# 對 misclassified index 50 加入三個隱藏節點
# 對 misclassified index 51 加入三個隱藏節點
# 對 misclassified index 52 加入三個隱藏節點
# 對 misclassified index 53 加入三個隱藏節點
# 對 misclassified index 54 加入三個隱藏節點
# 對 misclassified index 55 加入三個隱藏節點
# 對 misclassified index 56 加入三個隱藏節點
# 對 misclassified index 57 加入三個隱藏節點
# 對 misclassified index 59 加入三個隱藏節點
# 對 misclassified index 60 加入三個隱藏節點
# 對 misclassified index 61 加入三個隱藏節點
# 對 misclassified index 63 加入三個隱藏節點
# 對 misclassified index 64 加入三個隱藏節點
# 對 misclassified index 65 加入三個隱藏節點
# 對 misclassified index 68 加入三個隱藏節點
# 對 misclassified index 69 加入三個隱藏節點
# 對 misclassified index 70 加入三個隱藏節點
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# 對 misclassified index 134 加入三個隱藏節點
# 對 misclassified index 137 加入三個隱藏節點
# 對 misclassified index 139 加入三個隱藏節點
# 對 misclassified index 143 加入三個隱藏節點
# 對 misclassified index 144 加入三個隱藏節點
# 對 misclassified index 145 加入三個隱藏節點
# 對 misclassified index 146 加入三個隱藏節點
# 對 misclassified index 147 加入三個隱藏節點
# 對 misclassified index 149 加入三個隱藏節點
# 對 misclassified index 150 加入三個隱藏節點
# 對 misclassified index 151 加入三個隱藏節點
# 對 misclassified index 152 加入三個隱藏節點
# 對 misclassified index 154 加入三個隱藏節點
# 對 misclassified index 156 加入三個隱藏節點
# 對 misclassified index 157 加入三個隱藏節點
# 對 misclassified index 158 加入三個隱藏節點
# 對 misclassified index 159 加入三個隱藏節點
# 對 misclassified index 161 加入三個隱藏節點
# 對 misclassified index 162 加入三個隱藏節點
# 對 misclassified index 163 加入三個隱藏節點
# 對 misclassified index 165 加入三個隱藏節點
# 對 misclassified index 166 加入三個隱藏節點
# Number of hidden nodes after pruning: 20657 (no pruning done)
# 對 misclassified index 1 加入三個隱藏節點
# 對 misclassified index 2 加入三個隱藏節點
# 對 misclassified index 3 加入三個隱藏節點
# 對 misclassified index 5 加入三個隱藏節點
# 對 misclassified index 7 加入三個隱藏節點
# 對 misclassified index 8 加入三個隱藏節點
# 對 misclassified index 12 加入三個隱藏節點
# 對 misclassified index 14 加入三個隱藏節點
# 對 misclassified index 16 加入三個隱藏節點
# 對 misclassified index 18 加入三個隱藏節點
# 對 misclassified index 19 加入三個隱藏節點
# 對 misclassified index 20 加入三個隱藏節點
# 對 misclassified index 21 加入三個隱藏節點
# 對 misclassified index 23 加入三個隱藏節點
# 對 misclassified index 25 加入三個隱藏節點
# 對 misclassified index 26 加入三個隱藏節點
# 對 misclassified index 27 加入三個隱藏節點
# 對 misclassified index 28 加入三個隱藏節點
# 對 misclassified index 29 加入三個隱藏節點
# 對 misclassified index 31 加入三個隱藏節點
# 對 misclassified index 33 加入三個隱藏節點
# 對 misclassified index 34 加入三個隱藏節點
# 對 misclassified index 35 加入三個隱藏節點
# 對 misclassified index 39 加入三個隱藏節點
# 對 misclassified index 40 加入三個隱藏節點
# 對 misclassified index 43 加入三個隱藏節點
# 對 misclassified index 44 加入三個隱藏節點
# 對 misclassified index 45 加入三個隱藏節點
# 對 misclassified index 46 加入三個隱藏節點
# 對 misclassified index 47 加入三個隱藏節點
# 對 misclassified index 49 加入三個隱藏節點
# 對 misclassified index 50 加入三個隱藏節點
# 對 misclassified index 51 加入三個隱藏節點
# 對 misclassified index 52 加入三個隱藏節點
# 對 misclassified index 53 加入三個隱藏節點
# 對 misclassified index 54 加入三個隱藏節點
# 對 misclassified index 55 加入三個隱藏節點
# 對 misclassified index 56 加入三個隱藏節點
# 對 misclassified index 57 加入三個隱藏節點
# 對 misclassified index 59 加入三個隱藏節點
# 對 misclassified index 60 加入三個隱藏節點
# 對 misclassified index 61 加入三個隱藏節點
# 對 misclassified index 63 加入三個隱藏節點
# 對 misclassified index 64 加入三個隱藏節點
# 對 misclassified index 65 加入三個隱藏節點
# 對 misclassified index 68 加入三個隱藏節點
# 對 misclassified index 69 加入三個隱藏節點
# 對 misclassified index 70 加入三個隱藏節點
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# 對 misclassified index 134 加入三個隱藏節點
# 對 misclassified index 137 加入三個隱藏節點
# 對 misclassified index 139 加入三個隱藏節點
# 對 misclassified index 143 加入三個隱藏節點
# 對 misclassified index 144 加入三個隱藏節點
# 對 misclassified index 145 加入三個隱藏節點
# 對 misclassified index 146 加入三個隱藏節點
# 對 misclassified index 147 加入三個隱藏節點
# 對 misclassified index 149 加入三個隱藏節點
# 對 misclassified index 150 加入三個隱藏節點
# 對 misclassified index 151 加入三個隱藏節點
# 對 misclassified index 152 加入三個隱藏節點
# 對 misclassified index 154 加入三個隱藏節點
# 對 misclassified index 156 加入三個隱藏節點
# 對 misclassified index 157 加入三個隱藏節點
# 對 misclassified index 158 加入三個隱藏節點
# 對 misclassified index 159 加入三個隱藏節點
# 對 misclassified index 161 加入三個隱藏節點
# 對 misclassified index 162 加入三個隱藏節點
# 對 misclassified index 163 加入三個隱藏節點
# 對 misclassified index 165 加入三個隱藏節點
# 對 misclassified index 166 加入三個隱藏節點
# Number of hidden nodes after pruning: 20990 (no pruning done)
# 對 misclassified index 1 加入三個隱藏節點
# 對 misclassified index 2 加入三個隱藏節點
# 對 misclassified index 3 加入三個隱藏節點
# 對 misclassified index 5 加入三個隱藏節點
# 對 misclassified index 7 加入三個隱藏節點
# 對 misclassified index 8 加入三個隱藏節點
# 對 misclassified index 12 加入三個隱藏節點
# 對 misclassified index 14 加入三個隱藏節點
# 對 misclassified index 16 加入三個隱藏節點
# 對 misclassified index 18 加入三個隱藏節點
# 對 misclassified index 19 加入三個隱藏節點
# 對 misclassified index 20 加入三個隱藏節點
# 對 misclassified index 21 加入三個隱藏節點
# 對 misclassified index 23 加入三個隱藏節點
# 對 misclassified index 25 加入三個隱藏節點
# 對 misclassified index 26 加入三個隱藏節點
# 對 misclassified index 27 加入三個隱藏節點
# 對 misclassified index 28 加入三個隱藏節點
# 對 misclassified index 29 加入三個隱藏節點
# 對 misclassified index 31 加入三個隱藏節點
# 對 misclassified index 33 加入三個隱藏節點
# 對 misclassified index 34 加入三個隱藏節點
# 對 misclassified index 35 加入三個隱藏節點
# 對 misclassified index 39 加入三個隱藏節點
# 對 misclassified index 40 加入三個隱藏節點
# 對 misclassified index 43 加入三個隱藏節點
# 對 misclassified index 44 加入三個隱藏節點
# 對 misclassified index 45 加入三個隱藏節點
# 對 misclassified index 46 加入三個隱藏節點
# 對 misclassified index 47 加入三個隱藏節點
# 對 misclassified index 49 加入三個隱藏節點
# 對 misclassified index 50 加入三個隱藏節點
# 對 misclassified index 51 加入三個隱藏節點
# 對 misclassified index 52 加入三個隱藏節點
# 對 misclassified index 53 加入三個隱藏節點
# 對 misclassified index 54 加入三個隱藏節點
# 對 misclassified index 55 加入三個隱藏節點
# 對 misclassified index 56 加入三個隱藏節點
# 對 misclassified index 57 加入三個隱藏節點
# 對 misclassified index 59 加入三個隱藏節點
# 對 misclassified index 60 加入三個隱藏節點
# 對 misclassified index 61 加入三個隱藏節點
# 對 misclassified index 63 加入三個隱藏節點
# 對 misclassified index 64 加入三個隱藏節點
# 對 misclassified index 65 加入三個隱藏節點
# 對 misclassified index 68 加入三個隱藏節點
# 對 misclassified index 69 加入三個隱藏節點
# 對 misclassified index 70 加入三個隱藏節點
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# 對 misclassified index 134 加入三個隱藏節點
# 對 misclassified index 137 加入三個隱藏節點
# 對 misclassified index 139 加入三個隱藏節點
# 對 misclassified index 143 加入三個隱藏節點
# 對 misclassified index 144 加入三個隱藏節點
# 對 misclassified index 145 加入三個隱藏節點
# 對 misclassified index 146 加入三個隱藏節點
# 對 misclassified index 147 加入三個隱藏節點
# 對 misclassified index 149 加入三個隱藏節點
# 對 misclassified index 150 加入三個隱藏節點
# 對 misclassified index 151 加入三個隱藏節點
# 對 misclassified index 152 加入三個隱藏節點
# 對 misclassified index 154 加入三個隱藏節點
# 對 misclassified index 156 加入三個隱藏節點
# 對 misclassified index 157 加入三個隱藏節點
# 對 misclassified index 158 加入三個隱藏節點
# 對 misclassified index 159 加入三個隱藏節點
# 對 misclassified index 161 加入三個隱藏節點
# 對 misclassified index 162 加入三個隱藏節點
# 對 misclassified index 163 加入三個隱藏節點
# 對 misclassified index 165 加入三個隱藏節點
# 對 misclassified index 166 加入三個隱藏節點
# Number of hidden nodes after pruning: 21323 (no pruning done)
# 對 misclassified index 1 加入三個隱藏節點
# 對 misclassified index 2 加入三個隱藏節點
# 對 misclassified index 3 加入三個隱藏節點
# 對 misclassified index 5 加入三個隱藏節點
# 對 misclassified index 7 加入三個隱藏節點
# 對 misclassified index 8 加入三個隱藏節點
# 對 misclassified index 12 加入三個隱藏節點
# 對 misclassified index 14 加入三個隱藏節點
# 對 misclassified index 16 加入三個隱藏節點
# 對 misclassified index 18 加入三個隱藏節點
# 對 misclassified index 19 加入三個隱藏節點
# 對 misclassified index 20 加入三個隱藏節點
# 對 misclassified index 21 加入三個隱藏節點
# 對 misclassified index 23 加入三個隱藏節點
# 對 misclassified index 25 加入三個隱藏節點
# 對 misclassified index 26 加入三個隱藏節點
# 對 misclassified index 27 加入三個隱藏節點
# 對 misclassified index 28 加入三個隱藏節點
# 對 misclassified index 29 加入三個隱藏節點
# 對 misclassified index 31 加入三個隱藏節點
# 對 misclassified index 33 加入三個隱藏節點
# 對 misclassified index 34 加入三個隱藏節點
# 對 misclassified index 35 加入三個隱藏節點
# 對 misclassified index 39 加入三個隱藏節點
# 對 misclassified index 40 加入三個隱藏節點
# 對 misclassified index 43 加入三個隱藏節點
# 對 misclassified index 44 加入三個隱藏節點
# 對 misclassified index 45 加入三個隱藏節點
# 對 misclassified index 46 加入三個隱藏節點
# 對 misclassified index 47 加入三個隱藏節點
# 對 misclassified index 49 加入三個隱藏節點
# 對 misclassified index 50 加入三個隱藏節點
# 對 misclassified index 51 加入三個隱藏節點
# 對 misclassified index 52 加入三個隱藏節點
# 對 misclassified index 53 加入三個隱藏節點
# 對 misclassified index 54 加入三個隱藏節點
# 對 misclassified index 55 加入三個隱藏節點
# 對 misclassified index 56 加入三個隱藏節點
# 對 misclassified index 57 加入三個隱藏節點
# 對 misclassified index 59 加入三個隱藏節點
# 對 misclassified index 60 加入三個隱藏節點
# 對 misclassified index 61 加入三個隱藏節點
# 對 misclassified index 63 加入三個隱藏節點
# 對 misclassified index 64 加入三個隱藏節點
# 對 misclassified index 65 加入三個隱藏節點
# 對 misclassified index 68 加入三個隱藏節點
# 對 misclassified index 69 加入三個隱藏節點
# 對 misclassified index 70 加入三個隱藏節點
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# 對 misclassified index 134 加入三個隱藏節點
# 對 misclassified index 137 加入三個隱藏節點
# 對 misclassified index 139 加入三個隱藏節點
# 對 misclassified index 143 加入三個隱藏節點
# 對 misclassified index 144 加入三個隱藏節點
# 對 misclassified index 145 加入三個隱藏節點
# 對 misclassified index 146 加入三個隱藏節點
# 對 misclassified index 147 加入三個隱藏節點
# 對 misclassified index 149 加入三個隱藏節點
# 對 misclassified index 150 加入三個隱藏節點
# 對 misclassified index 151 加入三個隱藏節點
# 對 misclassified index 152 加入三個隱藏節點
# 對 misclassified index 154 加入三個隱藏節點
# 對 misclassified index 156 加入三個隱藏節點
# 對 misclassified index 157 加入三個隱藏節點
# 對 misclassified index 158 加入三個隱藏節點
# 對 misclassified index 159 加入三個隱藏節點
# 對 misclassified index 161 加入三個隱藏節點
# 對 misclassified index 162 加入三個隱藏節點
# 對 misclassified index 163 加入三個隱藏節點
# 對 misclassified index 165 加入三個隱藏節點
# 對 misclassified index 166 加入三個隱藏節點
# Number of hidden nodes after pruning: 21656 (no pruning done)
# 對 misclassified index 1 加入三個隱藏節點
# 對 misclassified index 2 加入三個隱藏節點
# 對 misclassified index 3 加入三個隱藏節點
# 對 misclassified index 5 加入三個隱藏節點
# 對 misclassified index 7 加入三個隱藏節點
# 對 misclassified index 8 加入三個隱藏節點
# 對 misclassified index 12 加入三個隱藏節點
# 對 misclassified index 14 加入三個隱藏節點
# 對 misclassified index 16 加入三個隱藏節點
# 對 misclassified index 18 加入三個隱藏節點
# 對 misclassified index 19 加入三個隱藏節點
# 對 misclassified index 20 加入三個隱藏節點
# 對 misclassified index 21 加入三個隱藏節點
# 對 misclassified index 23 加入三個隱藏節點
# 對 misclassified index 25 加入三個隱藏節點
# 對 misclassified index 26 加入三個隱藏節點
# 對 misclassified index 27 加入三個隱藏節點
# 對 misclassified index 28 加入三個隱藏節點
# 對 misclassified index 29 加入三個隱藏節點
# 對 misclassified index 31 加入三個隱藏節點
# 對 misclassified index 33 加入三個隱藏節點
# 對 misclassified index 34 加入三個隱藏節點
# 對 misclassified index 35 加入三個隱藏節點
# 對 misclassified index 39 加入三個隱藏節點
# 對 misclassified index 40 加入三個隱藏節點
# 對 misclassified index 43 加入三個隱藏節點
# 對 misclassified index 44 加入三個隱藏節點
# 對 misclassified index 45 加入三個隱藏節點
# 對 misclassified index 46 加入三個隱藏節點
# 對 misclassified index 47 加入三個隱藏節點
# 對 misclassified index 49 加入三個隱藏節點
# 對 misclassified index 50 加入三個隱藏節點
# 對 misclassified index 51 加入三個隱藏節點
# 對 misclassified index 52 加入三個隱藏節點
# 對 misclassified index 53 加入三個隱藏節點
# 對 misclassified index 54 加入三個隱藏節點
# 對 misclassified index 55 加入三個隱藏節點
# 對 misclassified index 56 加入三個隱藏節點
# 對 misclassified index 57 加入三個隱藏節點
# 對 misclassified index 59 加入三個隱藏節點
# 對 misclassified index 60 加入三個隱藏節點
# 對 misclassified index 61 加入三個隱藏節點
# 對 misclassified index 63 加入三個隱藏節點
# 對 misclassified index 64 加入三個隱藏節點
# 對 misclassified index 65 加入三個隱藏節點
# 對 misclassified index 68 加入三個隱藏節點
# 對 misclassified index 69 加入三個隱藏節點
# 對 misclassified index 70 加入三個隱藏節點
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# 對 misclassified index 134 加入三個隱藏節點
# 對 misclassified index 137 加入三個隱藏節點
# 對 misclassified index 139 加入三個隱藏節點
# 對 misclassified index 143 加入三個隱藏節點
# 對 misclassified index 144 加入三個隱藏節點
# 對 misclassified index 145 加入三個隱藏節點
# 對 misclassified index 146 加入三個隱藏節點
# 對 misclassified index 147 加入三個隱藏節點
# 對 misclassified index 149 加入三個隱藏節點
# 對 misclassified index 150 加入三個隱藏節點
# 對 misclassified index 151 加入三個隱藏節點
# 對 misclassified index 152 加入三個隱藏節點
# 對 misclassified index 154 加入三個隱藏節點
# 對 misclassified index 156 加入三個隱藏節點
# 對 misclassified index 157 加入三個隱藏節點
# 對 misclassified index 158 加入三個隱藏節點
# 對 misclassified index 159 加入三個隱藏節點
# 對 misclassified index 161 加入三個隱藏節點
# 對 misclassified index 162 加入三個隱藏節點
# 對 misclassified index 163 加入三個隱藏節點
# 對 misclassified index 165 加入三個隱藏節點
# 對 misclassified index 166 加入三個隱藏節點
# Number of hidden nodes after pruning: 21989 (no pruning done)
# 對 misclassified index 1 加入三個隱藏節點
# 對 misclassified index 2 加入三個隱藏節點
# 對 misclassified index 3 加入三個隱藏節點
# 對 misclassified index 5 加入三個隱藏節點
# 對 misclassified index 7 加入三個隱藏節點
# 對 misclassified index 8 加入三個隱藏節點
# 對 misclassified index 12 加入三個隱藏節點
# 對 misclassified index 14 加入三個隱藏節點
# 對 misclassified index 16 加入三個隱藏節點
# 對 misclassified index 18 加入三個隱藏節點
# 對 misclassified index 19 加入三個隱藏節點
# 對 misclassified index 20 加入三個隱藏節點
# 對 misclassified index 21 加入三個隱藏節點
# 對 misclassified index 23 加入三個隱藏節點
# 對 misclassified index 25 加入三個隱藏節點
# 對 misclassified index 26 加入三個隱藏節點
# 對 misclassified index 27 加入三個隱藏節點
# 對 misclassified index 28 加入三個隱藏節點
# 對 misclassified index 29 加入三個隱藏節點
# 對 misclassified index 31 加入三個隱藏節點
# 對 misclassified index 33 加入三個隱藏節點
# 對 misclassified index 34 加入三個隱藏節點
# 對 misclassified index 35 加入三個隱藏節點
# 對 misclassified index 39 加入三個隱藏節點
# 對 misclassified index 40 加入三個隱藏節點
# 對 misclassified index 43 加入三個隱藏節點
# 對 misclassified index 44 加入三個隱藏節點
# 對 misclassified index 45 加入三個隱藏節點
# 對 misclassified index 46 加入三個隱藏節點
# 對 misclassified index 47 加入三個隱藏節點
# 對 misclassified index 49 加入三個隱藏節點
# 對 misclassified index 50 加入三個隱藏節點
# 對 misclassified index 51 加入三個隱藏節點
# 對 misclassified index 52 加入三個隱藏節點
# 對 misclassified index 53 加入三個隱藏節點
# 對 misclassified index 54 加入三個隱藏節點
# 對 misclassified index 55 加入三個隱藏節點
# 對 misclassified index 56 加入三個隱藏節點
# 對 misclassified index 57 加入三個隱藏節點
# 對 misclassified index 59 加入三個隱藏節點
# 對 misclassified index 60 加入三個隱藏節點
# 對 misclassified index 61 加入三個隱藏節點
# 對 misclassified index 63 加入三個隱藏節點
# 對 misclassified index 64 加入三個隱藏節點
# 對 misclassified index 65 加入三個隱藏節點
# 對 misclassified index 68 加入三個隱藏節點
# 對 misclassified index 69 加入三個隱藏節點
# 對 misclassified index 70 加入三個隱藏節點
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# 對 misclassified index 134 加入三個隱藏節點
# 對 misclassified index 137 加入三個隱藏節點
# 對 misclassified index 139 加入三個隱藏節點
# 對 misclassified index 143 加入三個隱藏節點
# 對 misclassified index 144 加入三個隱藏節點
# 對 misclassified index 145 加入三個隱藏節點
# 對 misclassified index 146 加入三個隱藏節點
# 對 misclassified index 147 加入三個隱藏節點
# 對 misclassified index 149 加入三個隱藏節點
# 對 misclassified index 150 加入三個隱藏節點
# 對 misclassified index 151 加入三個隱藏節點
# 對 misclassified index 152 加入三個隱藏節點
# 對 misclassified index 154 加入三個隱藏節點
# 對 misclassified index 156 加入三個隱藏節點
# 對 misclassified index 157 加入三個隱藏節點
# 對 misclassified index 158 加入三個隱藏節點
# 對 misclassified index 159 加入三個隱藏節點
# 對 misclassified index 161 加入三個隱藏節點
# 對 misclassified index 162 加入三個隱藏節點
# 對 misclassified index 163 加入三個隱藏節點
# 對 misclassified index 165 加入三個隱藏節點
# 對 misclassified index 166 加入三個隱藏節點
# Number of hidden nodes after pruning: 22322 (no pruning done)
# 對 misclassified index 1 加入三個隱藏節點
# 對 misclassified index 2 加入三個隱藏節點
# 對 misclassified index 3 加入三個隱藏節點
# 對 misclassified index 5 加入三個隱藏節點
# 對 misclassified index 7 加入三個隱藏節點
# 對 misclassified index 8 加入三個隱藏節點
# 對 misclassified index 12 加入三個隱藏節點
# 對 misclassified index 14 加入三個隱藏節點
# 對 misclassified index 16 加入三個隱藏節點
# 對 misclassified index 18 加入三個隱藏節點
# 對 misclassified index 19 加入三個隱藏節點
# 對 misclassified index 20 加入三個隱藏節點
# 對 misclassified index 21 加入三個隱藏節點
# 對 misclassified index 23 加入三個隱藏節點
# 對 misclassified index 25 加入三個隱藏節點
# 對 misclassified index 26 加入三個隱藏節點
# 對 misclassified index 27 加入三個隱藏節點
# 對 misclassified index 28 加入三個隱藏節點
# 對 misclassified index 29 加入三個隱藏節點
# 對 misclassified index 31 加入三個隱藏節點
# 對 misclassified index 33 加入三個隱藏節點
# 對 misclassified index 34 加入三個隱藏節點
# 對 misclassified index 35 加入三個隱藏節點
# 對 misclassified index 39 加入三個隱藏節點
# 對 misclassified index 40 加入三個隱藏節點
# 對 misclassified index 43 加入三個隱藏節點
# 對 misclassified index 44 加入三個隱藏節點
# 對 misclassified index 45 加入三個隱藏節點
# 對 misclassified index 46 加入三個隱藏節點
# 對 misclassified index 47 加入三個隱藏節點
# 對 misclassified index 49 加入三個隱藏節點
# 對 misclassified index 50 加入三個隱藏節點
# 對 misclassified index 51 加入三個隱藏節點
# 對 misclassified index 52 加入三個隱藏節點
# 對 misclassified index 53 加入三個隱藏節點
# 對 misclassified index 54 加入三個隱藏節點
# 對 misclassified index 55 加入三個隱藏節點
# 對 misclassified index 56 加入三個隱藏節點
# 對 misclassified index 57 加入三個隱藏節點
# 對 misclassified index 59 加入三個隱藏節點
# 對 misclassified index 60 加入三個隱藏節點
# 對 misclassified index 61 加入三個隱藏節點
# 對 misclassified index 63 加入三個隱藏節點
# 對 misclassified index 64 加入三個隱藏節點
# 對 misclassified index 65 加入三個隱藏節點
# 對 misclassified index 68 加入三個隱藏節點
# 對 misclassified index 69 加入三個隱藏節點
# 對 misclassified index 70 加入三個隱藏節點
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# ...
# 對 misclassified index 63 加入三個隱藏節點
# 對 misclassified index 64 加入三個隱藏節點
# 對 misclassified index 65 加入三個隱藏節點
# 對 misclassified index 68 加入三個隱藏節點
# 對 misclassified index 69 加入三個隱藏節點
# 對 misclassified index 70 加入三個隱藏節點
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# 對 misclassified index 134 加入三個隱藏節點
# 對 misclassified index 137 加入三個隱藏節點
# 對 misclassified index 139 加入三個隱藏節點
# 對 misclassified index 143 加入三個隱藏節點
# 對 misclassified index 144 加入三個隱藏節點
# 對 misclassified index 145 加入三個隱藏節點
# 對 misclassified index 146 加入三個隱藏節點
# 對 misclassified index 147 加入三個隱藏節點
# 對 misclassified index 149 加入三個隱藏節點
# 對 misclassified index 150 加入三個隱藏節點
# 對 misclassified index 151 加入三個隱藏節點
# 對 misclassified index 152 加入三個隱藏節點
# 對 misclassified index 154 加入三個隱藏節點
# 對 misclassified index 156 加入三個隱藏節點
# 對 misclassified index 157 加入三個隱藏節點
# 對 misclassified index 158 加入三個隱藏節點
# 對 misclassified index 159 加入三個隱藏節點
# 對 misclassified index 161 加入三個隱藏節點
# 對 misclassified index 162 加入三個隱藏節點
# 對 misclassified index 163 加入三個隱藏節點
# 對 misclassified index 165 加入三個隱藏節點
# 對 misclassified index 166 加入三個隱藏節點
# Number of hidden nodes after pruning: 32312 (no pruning done)
# 對 misclassified index 1 加入三個隱藏節點
# 對 misclassified index 2 加入三個隱藏節點
# 對 misclassified index 3 加入三個隱藏節點
# 對 misclassified index 5 加入三個隱藏節點
# 對 misclassified index 7 加入三個隱藏節點
# 對 misclassified index 8 加入三個隱藏節點
# 對 misclassified index 12 加入三個隱藏節點
# 對 misclassified index 14 加入三個隱藏節點
# 對 misclassified index 16 加入三個隱藏節點
# 對 misclassified index 18 加入三個隱藏節點
# 對 misclassified index 19 加入三個隱藏節點
# 對 misclassified index 20 加入三個隱藏節點
# 對 misclassified index 21 加入三個隱藏節點
# 對 misclassified index 23 加入三個隱藏節點
# 對 misclassified index 25 加入三個隱藏節點
# 對 misclassified index 26 加入三個隱藏節點
# 對 misclassified index 27 加入三個隱藏節點
# 對 misclassified index 28 加入三個隱藏節點
# 對 misclassified index 29 加入三個隱藏節點
# 對 misclassified index 31 加入三個隱藏節點
# 對 misclassified index 33 加入三個隱藏節點
# 對 misclassified index 34 加入三個隱藏節點
# 對 misclassified index 35 加入三個隱藏節點
# 對 misclassified index 39 加入三個隱藏節點
# 對 misclassified index 40 加入三個隱藏節點
# 對 misclassified index 43 加入三個隱藏節點
# 對 misclassified index 44 加入三個隱藏節點
# 對 misclassified index 45 加入三個隱藏節點
# 對 misclassified index 46 加入三個隱藏節點
# 對 misclassified index 47 加入三個隱藏節點
# 對 misclassified index 49 加入三個隱藏節點
# 對 misclassified index 50 加入三個隱藏節點
# 對 misclassified index 51 加入三個隱藏節點
# 對 misclassified index 52 加入三個隱藏節點
# 對 misclassified index 53 加入三個隱藏節點
# 對 misclassified index 54 加入三個隱藏節點
# 對 misclassified index 55 加入三個隱藏節點
# 對 misclassified index 56 加入三個隱藏節點
# 對 misclassified index 57 加入三個隱藏節點
# 對 misclassified index 59 加入三個隱藏節點
# 對 misclassified index 60 加入三個隱藏節點
# 對 misclassified index 61 加入三個隱藏節點
# 對 misclassified index 63 加入三個隱藏節點
# 對 misclassified index 64 加入三個隱藏節點
# 對 misclassified index 65 加入三個隱藏節點
# 對 misclassified index 68 加入三個隱藏節點
# 對 misclassified index 69 加入三個隱藏節點
# 對 misclassified index 70 加入三個隱藏節點
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# 對 misclassified index 134 加入三個隱藏節點
# 對 misclassified index 137 加入三個隱藏節點
# 對 misclassified index 139 加入三個隱藏節點
# 對 misclassified index 143 加入三個隱藏節點
# 對 misclassified index 144 加入三個隱藏節點
# 對 misclassified index 145 加入三個隱藏節點
# 對 misclassified index 146 加入三個隱藏節點
# 對 misclassified index 147 加入三個隱藏節點
# 對 misclassified index 149 加入三個隱藏節點
# 對 misclassified index 150 加入三個隱藏節點
# 對 misclassified index 151 加入三個隱藏節點
# 對 misclassified index 152 加入三個隱藏節點
# 對 misclassified index 154 加入三個隱藏節點
# 對 misclassified index 156 加入三個隱藏節點
# 對 misclassified index 157 加入三個隱藏節點
# 對 misclassified index 158 加入三個隱藏節點
# 對 misclassified index 159 加入三個隱藏節點
# 對 misclassified index 161 加入三個隱藏節點
# 對 misclassified index 162 加入三個隱藏節點
# 對 misclassified index 163 加入三個隱藏節點
# 對 misclassified index 165 加入三個隱藏節點
# 對 misclassified index 166 加入三個隱藏節點
# Number of hidden nodes after pruning: 32645 (no pruning done)
# 對 misclassified index 1 加入三個隱藏節點
# 對 misclassified index 2 加入三個隱藏節點
# 對 misclassified index 3 加入三個隱藏節點
# 對 misclassified index 5 加入三個隱藏節點
# 對 misclassified index 7 加入三個隱藏節點
# 對 misclassified index 8 加入三個隱藏節點
# 對 misclassified index 12 加入三個隱藏節點
# 對 misclassified index 14 加入三個隱藏節點
# 對 misclassified index 16 加入三個隱藏節點
# 對 misclassified index 18 加入三個隱藏節點
# 對 misclassified index 19 加入三個隱藏節點
# 對 misclassified index 20 加入三個隱藏節點
# 對 misclassified index 21 加入三個隱藏節點
# 對 misclassified index 23 加入三個隱藏節點
# 對 misclassified index 25 加入三個隱藏節點
# 對 misclassified index 26 加入三個隱藏節點
# 對 misclassified index 27 加入三個隱藏節點
# 對 misclassified index 28 加入三個隱藏節點
# 對 misclassified index 29 加入三個隱藏節點
# 對 misclassified index 31 加入三個隱藏節點
# 對 misclassified index 33 加入三個隱藏節點
# 對 misclassified index 34 加入三個隱藏節點
# 對 misclassified index 35 加入三個隱藏節點
# 對 misclassified index 39 加入三個隱藏節點
# 對 misclassified index 40 加入三個隱藏節點
# 對 misclassified index 43 加入三個隱藏節點
# 對 misclassified index 44 加入三個隱藏節點
# 對 misclassified index 45 加入三個隱藏節點
# 對 misclassified index 46 加入三個隱藏節點
# 對 misclassified index 47 加入三個隱藏節點
# 對 misclassified index 49 加入三個隱藏節點
# 對 misclassified index 50 加入三個隱藏節點
# 對 misclassified index 51 加入三個隱藏節點
# 對 misclassified index 52 加入三個隱藏節點
# 對 misclassified index 53 加入三個隱藏節點
# 對 misclassified index 54 加入三個隱藏節點
# 對 misclassified index 55 加入三個隱藏節點
# 對 misclassified index 56 加入三個隱藏節點
# 對 misclassified index 57 加入三個隱藏節點
# 對 misclassified index 59 加入三個隱藏節點
# 對 misclassified index 60 加入三個隱藏節點
# 對 misclassified index 61 加入三個隱藏節點
# 對 misclassified index 63 加入三個隱藏節點
# 對 misclassified index 64 加入三個隱藏節點
# 對 misclassified index 65 加入三個隱藏節點
# 對 misclassified index 68 加入三個隱藏節點
# 對 misclassified index 69 加入三個隱藏節點
# 對 misclassified index 70 加入三個隱藏節點
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# 對 misclassified index 134 加入三個隱藏節點
# 對 misclassified index 137 加入三個隱藏節點
# 對 misclassified index 139 加入三個隱藏節點
# 對 misclassified index 143 加入三個隱藏節點
# 對 misclassified index 144 加入三個隱藏節點
# 對 misclassified index 145 加入三個隱藏節點
# 對 misclassified index 146 加入三個隱藏節點
# 對 misclassified index 147 加入三個隱藏節點
# 對 misclassified index 149 加入三個隱藏節點
# 對 misclassified index 150 加入三個隱藏節點
# 對 misclassified index 151 加入三個隱藏節點
# 對 misclassified index 152 加入三個隱藏節點
# 對 misclassified index 154 加入三個隱藏節點
# 對 misclassified index 156 加入三個隱藏節點
# 對 misclassified index 157 加入三個隱藏節點
# 對 misclassified index 158 加入三個隱藏節點
# 對 misclassified index 159 加入三個隱藏節點
# 對 misclassified index 161 加入三個隱藏節點
# 對 misclassified index 162 加入三個隱藏節點
# 對 misclassified index 163 加入三個隱藏節點
# 對 misclassified index 165 加入三個隱藏節點
# 對 misclassified index 166 加入三個隱藏節點
# Number of hidden nodes after pruning: 32978 (no pruning done)
# 對 misclassified index 1 加入三個隱藏節點
# 對 misclassified index 2 加入三個隱藏節點
# 對 misclassified index 3 加入三個隱藏節點
# 對 misclassified index 5 加入三個隱藏節點
# 對 misclassified index 7 加入三個隱藏節點
# 對 misclassified index 8 加入三個隱藏節點
# 對 misclassified index 12 加入三個隱藏節點
# 對 misclassified index 14 加入三個隱藏節點
# 對 misclassified index 16 加入三個隱藏節點
# 對 misclassified index 18 加入三個隱藏節點
# 對 misclassified index 19 加入三個隱藏節點
# 對 misclassified index 20 加入三個隱藏節點
# 對 misclassified index 21 加入三個隱藏節點
# 對 misclassified index 23 加入三個隱藏節點
# 對 misclassified index 25 加入三個隱藏節點
# 對 misclassified index 26 加入三個隱藏節點
# 對 misclassified index 27 加入三個隱藏節點
# 對 misclassified index 28 加入三個隱藏節點
# 對 misclassified index 29 加入三個隱藏節點
# 對 misclassified index 31 加入三個隱藏節點
# 對 misclassified index 33 加入三個隱藏節點
# 對 misclassified index 34 加入三個隱藏節點
# 對 misclassified index 35 加入三個隱藏節點
# 對 misclassified index 39 加入三個隱藏節點
# 對 misclassified index 40 加入三個隱藏節點
# 對 misclassified index 43 加入三個隱藏節點
# 對 misclassified index 44 加入三個隱藏節點
# 對 misclassified index 45 加入三個隱藏節點
# 對 misclassified index 46 加入三個隱藏節點
# 對 misclassified index 47 加入三個隱藏節點
# 對 misclassified index 49 加入三個隱藏節點
# 對 misclassified index 50 加入三個隱藏節點
# 對 misclassified index 51 加入三個隱藏節點
# 對 misclassified index 52 加入三個隱藏節點
# 對 misclassified index 53 加入三個隱藏節點
# 對 misclassified index 54 加入三個隱藏節點
# 對 misclassified index 55 加入三個隱藏節點
# 對 misclassified index 56 加入三個隱藏節點
# 對 misclassified index 57 加入三個隱藏節點
# 對 misclassified index 59 加入三個隱藏節點
# 對 misclassified index 60 加入三個隱藏節點
# 對 misclassified index 61 加入三個隱藏節點
# 對 misclassified index 63 加入三個隱藏節點
# 對 misclassified index 64 加入三個隱藏節點
# 對 misclassified index 65 加入三個隱藏節點
# 對 misclassified index 68 加入三個隱藏節點
# 對 misclassified index 69 加入三個隱藏節點
# 對 misclassified index 70 加入三個隱藏節點
# 對 misclassified index 71 加入三個隱藏節點
# 對 misclassified index 73 加入三個隱藏節點
# 對 misclassified index 74 加入三個隱藏節點
# 對 misclassified index 75 加入三個隱藏節點
# 對 misclassified index 76 加入三個隱藏節點
# 對 misclassified index 78 加入三個隱藏節點
# 對 misclassified index 80 加入三個隱藏節點
# 對 misclassified index 82 加入三個隱藏節點
# 對 misclassified index 83 加入三個隱藏節點
# 對 misclassified index 84 加入三個隱藏節點
# 對 misclassified index 85 加入三個隱藏節點
# 對 misclassified index 86 加入三個隱藏節點
# 對 misclassified index 87 加入三個隱藏節點
# 對 misclassified index 88 加入三個隱藏節點
# 對 misclassified index 89 加入三個隱藏節點
# 對 misclassified index 90 加入三個隱藏節點
# 對 misclassified index 91 加入三個隱藏節點
# 對 misclassified index 93 加入三個隱藏節點
# 對 misclassified index 94 加入三個隱藏節點
# 對 misclassified index 95 加入三個隱藏節點
# 對 misclassified index 97 加入三個隱藏節點
# 對 misclassified index 98 加入三個隱藏節點
# 對 misclassified index 100 加入三個隱藏節點
# 對 misclassified index 103 加入三個隱藏節點
# 對 misclassified index 112 加入三個隱藏節點
# 對 misclassified index 113 加入三個隱藏節點
# 對 misclassified index 114 加入三個隱藏節點
# 對 misclassified index 116 加入三個隱藏節點
# 對 misclassified index 117 加入三個隱藏節點
# 對 misclassified index 119 加入三個隱藏節點
# 對 misclassified index 120 加入三個隱藏節點
# 對 misclassified index 121 加入三個隱藏節點
# 對 misclassified index 123 加入三個隱藏節點
# 對 misclassified index 124 加入三個隱藏節點
# 對 misclassified index 125 加入三個隱藏節點
# 對 misclassified index 126 加入三個隱藏節點
# 對 misclassified index 127 加入三個隱藏節點
# 對 misclassified index 128 加入三個隱藏節點
# 對 misclassified index 129 加入三個隱藏節點
# 對 misclassified index 130 加入三個隱藏節點
# 對 misclassified index 132 加入三個隱藏節點
# 對 misclassified index 134 加入三個隱藏節點
# 對 misclassified index 137 加入三個隱藏節點
# 對 misclassified index 139 加入三個隱藏節點
# 對 misclassified index 143 加入三個隱藏節點
# 對 misclassified index 144 加入三個隱藏節點
# 對 misclassified index 145 加入三個隱藏節點
# 對 misclassified index 146 加入三個隱藏節點
# 對 misclassified index 147 加入三個隱藏節點
# 對 misclassified index 149 加入三個隱藏節點
# 對 misclassified index 150 加入三個隱藏節點
# 對 misclassified index 151 加入三個隱藏節點
# 對 misclassified index 152 加入三個隱藏節點
# 對 misclassified index 154 加入三個隱藏節點
# 對 misclassified index 156 加入三個隱藏節點
# 對 misclassified index 157 加入三個隱藏節點
# 對 misclassified index 158 加入三個隱藏節點
# 對 misclassified index 159 加入三個隱藏節點
# 對 misclassified index 161 加入三個隱藏節點
# 對 misclassified index 162 加入三個隱藏節點
# 對 misclassified index 163 加入三個隱藏節點
# 對 misclassified index 165 加入三個隱藏節點
# 對 misclassified index 166 加入三個隱藏節點
# [1.7600593566894531, 1.356287956237793, 1.3136076927185059, 1.322570562362671, 1.5359816551208496, 1.346361517906189, 1.4030019044876099, 1.4377374649047852, 1.3472603559494019, 1.4142993688583374, 1.4659299850463867, 1.29794180393219, 1.3384896516799927, 1.532114863395691, 1.3893877267837524, 1.3746999502182007, 1.4958070516586304, 1.338724970817566, 1.3946778774261475, 1.2824840545654297, 1.3946866989135742, 1.4229458570480347, 1.444474458694458, 1.3764997720718384, 1.3871606588363647, 1.45010244846344, 1.4095842838287354, 1.4731104373931885, 1.2954180240631104, 1.4483853578567505, 1.2842342853546143, 1.2959744930267334, 1.3749566078186035, 1.3608518838882446, 1.243072748184204, 1.4164522886276245, 1.5252443552017212, 1.3842198848724365, 1.2678686380386353, 1.3997684717178345, 1.2652933597564697, 1.3333697319030762, 1.1970291137695312, 1.4334443807601929, 1.3384497165679932, 1.3870214223861694, 1.2551113367080688, 1.4884862899780273, 1.3516993522644043, 1.2899408340454102, 1.386768102645874, 1.4363492727279663, 1.4526716470718384, 1.2844136953353882, 1.3466205596923828, 1.3370904922485352, 1.3351224660873413, 1.4718290567398071, 1.3889292478561401, 1.3334943056106567, 1.3330484628677368, 1.4277153015136719, 1.4004729986190796, 1.3328180313110352, 1.3805692195892334, 1.3550082445144653, 1.2900590896606445, 1.3614389896392822, 1.4959230422973633, 1.382188320159912, 1.3825637102127075, 1.2976481914520264, 1.3048473596572876, 1.3132669925689697, 1.2721420526504517, 1.333799123764038, 1.4155216217041016, 1.3591582775115967, 1.2177420854568481, 1.2789709568023682, 1.2445284128189087, 1.2316210269927979, 1.344637155532837, 1.313348412513733, 1.2788270711898804, 1.2794708013534546, 1.2962380647659302, 1.3752740621566772, 1.2766467332839966, 1.2753134965896606, 1.2792435884475708, 1.3572289943695068, 1.2609124183654785, 1.3277921676635742, 1.3096600770950317, 1.2865209579467773, 1.284881830215454, 1.4054605960845947, 1.3807885646820068, 1.262228012084961]

# %%
plt.plot(range(len(losses)), losses)
plt.ylabel('Loss/Error')
plt.xlabel('Epoch')
plt.show()

criterion = nn.CrossEntropyLoss()

# 評估模型效能
with torch.no_grad():
    y_eval = model5(X_test)
    loss = criterion(y_eval, y_test)
    correct = (y_eval.argmax(dim=1) == y_test).sum().item()

print(f'Validation Loss is: {loss.item()}')
print(f'Accuracy is: {correct / len(y_test)}')
# Out:
# Validation Loss is: 1.2475619316101074
# Accuracy is: 0.30952380952380953
